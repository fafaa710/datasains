# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mlt
# %matplotlib inline

# %%
data=pd.read_csv('heart.csv')
print(data)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %%
#mengecek missing value
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
data1=data[data["HeartDisease"]==1]
data1.hist(column='Age',grid=0,color='#61dafb',edgecolor='black');
ax=plt.gca()
ax.set_facecolor('white')
plt.title('Distribusi Usia Pengidap Penyakit Jantung');

# %%
values=data['Sex'].value_counts()
show_JenisKelamin = data['Sex'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_JenisKelamin,values)
plt.title('Jumlah Data Berdasarkan Jenis Kelamin')
plt.show()

# %%
JenisKelamin=data.groupby("Sex")
JenisKelamin["Sex"].count()
# Out:
# Sex
# F    193
# M    725
# Name: Sex, dtype: int64

# %% [markdown]
# F untuk Female atau Perempuan, M untuk Male atau Laki-laki

# %%
values=data['ChestPainType'].value_counts()
show_TipeNyeriDada = data['ChestPainType'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_TipeNyeriDada,values)
plt.title('Jumlah Data Berdasarkan Tipe Nyeri Dada')
plt.show()

# %%
TipeNyeriDada=data.groupby("ChestPainType")
TipeNyeriDada["ChestPainType"].count()
# Out:
# ChestPainType
# ASY    496
# ATA    173
# NAP    203
# TA      46
# Name: ChestPainType, dtype: int64

# %%
data1.hist(column='RestingBP',grid=0,color='#61dafb',edgecolor='black');
ax=plt.gca()
ax.set_facecolor('white')
plt.title('Distribusi Tekanan Darah Pengidap Penyakit Jantung');

# %%
data1.hist(column='Cholesterol',grid=0,color='#61dafb',edgecolor='black');
ax=plt.gca()
ax.set_facecolor('white')
plt.title('Distribusi Kolesterol Pengidap Penyakit Jantung');

# %%
values=data['FastingBS'].value_counts()
show_FastingBS = data['FastingBS'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_FastingBS,values)
plt.title('Jumlah Data Berdasarkan Kecepatan Gula Darah')
plt.show()

# %%
KecepatanGulaDarah=data.groupby("FastingBS")
KecepatanGulaDarah["FastingBS"].count()
# Out:
# FastingBS
# 0    704
# 1    214
# Name: FastingBS, dtype: int64

# %%
values=data['RestingECG'].value_counts()
show_RestingECG = data['RestingECG'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_RestingECG,values)
plt.title('Jumlah Data Berdasarkan Resting ECG')
plt.show()

# %%
RestingECG=data.groupby("RestingECG")
RestingECG["RestingECG"].count()
# Out:
# RestingECG
# LVH       188
# Normal    552
# ST        178
# Name: RestingECG, dtype: int64

# %%
data1.hist(column='MaxHR',grid=0,color='#61dafb',edgecolor='black');
ax=plt.gca()
ax.set_facecolor('white')
plt.title('Distribusi Maksimum Detak Jantung Pengidap Penyakit Jantung');

# %%
values=data['ExerciseAngina'].value_counts()
show_ExerciseAngina = data['ExerciseAngina'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_ExerciseAngina,values)
plt.title('Jumlah Data Berdasarkan Exercise Angina')
plt.show()

# %%
ExerciseAngina=data.groupby("ExerciseAngina")
ExerciseAngina["ExerciseAngina"].count()
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: ExerciseAngina, dtype: int64

# %%
data1.hist(column='Oldpeak',grid=0,color='#61dafb',edgecolor='black');
ax=plt.gca()
ax.set_facecolor('white')
plt.title('Distribusi Oldpeak Pada Pasien Pengidap Penyakit Jantung');

# %%
values=data['ST_Slope'].value_counts()
show_ST_Slope = data['ST_Slope'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_ST_Slope,values)
plt.title('Jumlah Data Berdasarkan Kemiringan ST')
plt.show()

# %%
ST_Slope=data.groupby("ST_Slope")
ST_Slope["ST_Slope"].count()
# Out:
# ST_Slope
# Down     63
# Flat    460
# Up      395
# Name: ST_Slope, dtype: int64

# %%
values=data['HeartDisease'].value_counts()
show_HeartDisease = data['HeartDisease'].unique()
plt.figure(figsize=(4,6))
plt.bar(show_HeartDisease,values)
plt.title('Jumlah Data Berdasarkan Pasien Penyakit Jantung')
plt.show()

# %%
HeartDisease=data.groupby("HeartDisease")
HeartDisease["HeartDisease"].count()
# Out:
# HeartDisease
# 0    410
# 1    508
# Name: HeartDisease, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='ChestPainType',hue='HeartDisease',data=data, multiple="dodge",shrink=0.8)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Sex',hue='HeartDisease',data=data)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='Age',hue='HeartDisease',data=data, multiple="dodge", shrink=0.7)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='MaxHR',hue='HeartDisease',data=data,multiple='dodge', shrink= 0.7,kde=True)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='ExerciseAngina',hue='HeartDisease',data=data)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='Oldpeak',hue='HeartDisease',data=data,multiple='dodge', shrink= 0.7,kde=True)
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.histplot(x='ST_Slope',hue='HeartDisease',data=data,multiple='dodge', shrink= 0.7)
plt.show()

# %%
datap=data[data["HeartDisease"]==1]
sns.displot(data=data,y='Cholesterol',x='Age', hue='HeartDisease',palette='mako',cmap='coolwarm');
plt.title('Pengaruh Usia Terhadap Kadar Kolesterol');

# %%
sns.pairplot(data,hue="HeartDisease");

# %%
sns.displot(data=data,x='MaxHR',y='Cholesterol', hue='HeartDisease',palette='mako',cmap='coolwarm');
plt.title('Kolesterol vs Maksimum Detak Jantung');

# %%
cor=data.corr()
plt.figure(figsize=(7,7))
sns.heatmap(cor, annot=True);
plt.title('Korelasi antara 6 variabel dan Penyakit Jantung (Heart Disease)');
